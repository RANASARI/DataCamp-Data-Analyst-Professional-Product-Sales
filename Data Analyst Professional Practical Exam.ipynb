# %% [markdown]
# # Data Analyst Professional Practical Exam

# %% [markdown]
# ## Data Validation
#
# The dataset contains **15000 rows and 8 columns** before cleaning and validation. I have validated all the columns against the criteria in the dataset table:
#
# - **week:** The values of this column are between 1 and 6 without missing values, same as the description. No cleaning is needed.
# - **sales_method:** 5 unique values without missing values. 23 values were "em + call". These values were replaced with the "Email + Call". Also, 10 values were "email". These values were replaced with the "Email". Hereby, 3 sales method (Call, Email, and Email + Call), same as the description.
# - **customer_id:** 15000 unique values without missing values, same as the description. No cleaning is needed.
# - **nb_sold:** Numeric values without missing values, same as the description. No cleaning is needed.
# - **revenue:** Numeric values with 1074 missing values, same as the description. Missing values were dropped. All values were rounded to 2 decimal places.
# - **years_as_customer:** Numeric values without missing values. Pens and Printers was founded in 1984. Two values over 39 years (47 & 63) were dropped.
# - **nb_site_visits:** Numeric values, same as the description. No cleaning is needed.
# - **state:** 50 unique values without missing values, same as the description. No cleaning is needed.
#
# After the data validation, the dataset contains **13924 rows and 8 columns** without missing values.
#
# ## How many customers were there for each approach?
#
# ![1](1.jpg)
#
# From the record of the last 6 weeks, nearly half of the sales were made through the 'Email' sales method, followed by the 'Call' sales method. Additionally, it's evident that the number of sales with the 'Email' sales method is nearly one and a half times the number of sales with the 'Call' sales method.
#
# ## What does the spread of the revenue look like overall? And for each method?
#
# We want to examine the distribution of revenue from the last 6 weeks. Upon reviewing the revenue distribution, it appears that the majority of the revenue falls within the 40-110 range. The distribution is most concentrated between 40-55 and 80-95 specifically.
#
# ![2](2.jpg)
#
#
# The bar chart below shows the distribution of total revenue by sales methods. 51.4% of the revenue is generated through the 'Email' sales method, 31.2% through the 'Email + Call' sales method, and finally, 17.4% through the 'Call' sales method.
#
# ![5](5.jpg)
#
#
# Based on the multiple boxplots below, we observe that the revenue range in the 'Email + Call' sales method is more pronounced compared to other sales methods. The majority of the revenue generated through the 'Email + Call' method falls within the range of 156 to 191, which is higher than that of 'Email' and 'Call'.
#
# ![3](3.jpg)
#
# By examining these boxplots, it becomes evident that the 'Call' sales method was the least productive. This conclusion is drawn from the fact that the majority of revenue amounts for the 'Call' sales method fall within the range of 41-53, which is significantly lower than the ranges for the other sales methods. This clarifies why 'Call' contributed the smallest percentage (17.4%) to the total revenue.
#
# ![4](4.jpg)
#
# ## Was there any difference in revenue over time for each of the methods?
#
# ![6](6.jpg)
#
# When we look the revenue by week and sales method, we observe that in the first week, revenue was significantly higher through the 'Email' sales method compared to other sales methods. However, the 'Email' sales method consistently experienced a decline over the 6-week period, becoming the least revenue-generating method by the 6th week. Although the 'Call' sales method showed a slight improvement over the 6-week period, it remained at roughly the same revenue level by the end of the 6th week.
#
# The noteworthy observation from the line chart above is that the 'Email + Call' sales method, which generated the lowest revenue in the first week, reached the top by the end of the 6th week.
#
#
# ## Which sales method would you recommend continuing to use?
#
# When examining the average revenue for each sales method by week, we can observe that the mean revenue for the 'Email + Call' sales method starts at the highest point, whereas the 'Call' sales method generates the lowest mean revenue.
#
# ![7](7.jpg)
#
# When we analyze all the data, we conclude that the 'Call' sales method is the least efficient sales method. Not only does it contribute the least in terms of revenue, but it also requires team members to spend 30 minutes per customer. It appears to be a cumbersome sales method and, as we can see from the charts, the least efficient.
#
# The 'Email' sales method holds a significant position in both revenue distribution and requires minimal workload for the team. However, over the six-week period, the revenue generated through the 'Email' sales method has declined.
#
# In light of this situation, we should use the 'Email + Call' sales method. Sending product information emails to customers first, followed by a call from our sales team a week later to discuss their needs and how this new product can support their business has proven to yield the highest sales.
#
# ![8](8.jpg)
#
# ![9](9.jpg)
#
# As seen in the chart and data table above, the revenue generated from 2,223 sales using the 'Email + Call' sales method amounts to 408,257 USD. On the other hand, the revenue from 6,921 sales using the 'Email' sales method totals 672,221 USD. If we increase the number of sales made through the 'Email + Call' method, we can potentially achieve significantly higher revenue compared to other sales methods. At the same time, we should focus on increasing the revenue range of sales made through the 'Email' sales method.
#
# ## Business Metric
#
# Since our objective is to enhance revenue using the most effective sales method, I would recommend using the average revenue for each sales method by week as our metric.
#
# Based on our data from the last 6 weeks, 31.2% of the revenue is generated through the 'Email + Call' sales method. Therefore, if this percentage increases in the coming weeks, it would be a very positive indicator toward achieving our goal.
#
#
# ## Recommendation
#
# For the following weeks, I would recommend we can focus on the following steps:
#
# - **Prioritize 'Email + Call':** Focus on expanding the successful 'Email + Call' method, which consistently increased revenue over six weeks.
# - **Optimize 'Email' Sales:** Improve the 'Email' method due to a declining trend, considering email content, targeting, and timing enhancements.
# - **Continuous Monitoring:** Keep a close eye on each method's performance with weekly tracking to guide informed decisions.
# - **Research and Innovation:** Explore factors contributing to the 'Email + Call' method's success and remain open to new sales strategies.
# - **Feedback Loop:** Establish a feedback loop with the sales team to adapt strategies based on customer responses and challenges.
# - **Set Growth Targets:** Define clear growth targets for each method and regularly assess progress to stay motivated.
# - **Data Quality:** Ensure data accuracy and completeness to support ongoing analysis and decision-making. Improve data quality by addressing missing values, especially in the revenue column.
